# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\APJ\Downloads\StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %% [markdown]
# ### Number of Male and Females in the test

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# ### Parent's Level of Education

# %%
plt.figure(figsize = (14,6))
df['parental level of education'].hist()
# Out:
# <AxesSubplot:>

# %%
df['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# ### Highest Math,Reading and Writing Scores based on Gender

# %%
df.groupby('gender').mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %% [markdown]
# . Female students have the highest average reading and writing score<br>
# . Male Students have the highest average score on Maths

# %% [markdown]
# ### Highest Math,Reading and Writing Scores based on completion of Preparation Course

# %%
df.groupby('test preparation course').mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %% [markdown]
# . The sudents who have completed the preparation course have scored more than those who have not.

# %% [markdown]
# ### Scoring Variation per Gender

# %%
df.groupby('gender').var()
# Out:
#         math score  reading score  writing score
# gender
# female  256.958593     207.677438     220.369327
# male    211.889097     200.211010     202.413924

# %% [markdown]
# . Male students have less variation among their scores than Female students

# %% [markdown]
# ### Scoring Variation based on completion of Preparation Course

# %%
df.groupby('test preparation course').var()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                210.884027     183.265864     175.202612
# none                     246.668662     213.419851     226.251739

# %% [markdown]
# . Students who have completed the course have much less variation among their scores

# %% [markdown]
# ### Top 25% of students based on Maths score

# %%
e=df.sort_values(by='math score',ascending=False)

# %%
n = 25
e.head(int(len(e)*(n/100)))
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 856    male        group E            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 854    male        group D            some high school      standard
# 853    male        group D          associate's degree  free/reduced
# 852    male        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# . This is the IDs of students who earned the bonus points

# %%
list(e.index)
# Out:
# [999,
#  996,
#  515,
#  517,
#  516,
#  997,
#  998,
#  995,
#  513,
#  514,
#  994,
#  993,
#  512,
#  992,
#  991,
#  989,
#  510,
#  511,
#  990,
#  509,
#  508,
#  988,
#  507,
#  987,
#  505,
#  506,
#  982,
#  983,
#  985,
#  986,
#  984,
#  504,
#  503,
#  980,
#  981,
#  978,
#  979,
#  499,
#  502,
#  501,
#  500,
#  973,
#  497,
#  498,
#  975,
#  977,
#  974,
#  972,
#  976,
#  971,
#  969,
#  967,
#  968,
#  495,
#  970,
#  965,
#  496,
#  966,
#  964,
#  494,
#  959,
#  960,
#  961,
#  962,
#  963,
#  488,
#  493,
#  492,
#  491,
#  490,
#  956,
#  489,
#  955,
#  951,
#  950,
#  953,
#  954,
#  958,
#  957,
#  952,
#  486,
#  487,
#  485,
#  943,
#  948,
#  947,
#  946,
#  945,
#  944,
#  942,
#  941,
#  940,
#  939,
#  483,
#  484,
#  949,
#  933,
#  481,
#  934,
#  935,
#  936,
#  937,
#  938,
#  482,
#  478,
#  479,
#  480,
#  477,
#  476,
#  475,
#  474,
#  473,
#  932,
#  931,
#  930,
#  929,
#  928,
#  927,
#  926,
#  471,
#  472,
#  925,
#  923,
#  922,
#  921,
# ...
